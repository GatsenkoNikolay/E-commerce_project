# %% [markdown]
# # Проект e-commerce

# %% [markdown]
#  <p style="font-size:18px">Необходимо проанализировать совершенные пользователями покупки и ответить на вопросы:</p>
#  <ul style="font-size: 20px; line-height: 1.5;">
#   <li>1. Сколько пользователей, которые совершили покупку только один раз?</li>
#   <li>2. Сколько заказов в месяц в среднем не доставляется по разным причинам (вывести детализацию по причинам)?</li>
#   <li>3. По каждому товару определить, в какой день недели товар чаще всего покупается.</li>
#   <li>4. Сколько у каждого из пользователей в среднем покупок в неделю (по месяцам)?</li>
#   <li>5. Выполнить когортный анализ пользователей. В период с января по декабрь выявите когорту с самым высоким retention на 3-й месяц.</li>
#   <li>6. Построить RFM-сегментацию пользователей.</li>
# </ul>
#
# ##### Описание данных:
# <li>olist_customers_datase.csv — таблица с уникальными идентификаторами пользователей</li></br>
#
# customer_id — позаказный идентификатор пользователя
#
# customer_unique_id —  уникальный идентификатор пользователя
#
# customer_zip_code_prefix —  почтовый индекс пользователя
#
# customer_city —  город доставки пользователя
#
# customer_state —  штат доставки пользователя
#
# <li>olist_orders_dataset.csv —  таблица заказов</li></br>
#
# order_id —  уникальный идентификатор заказа
#
# customer_id —  позаказный идентификатор пользователя
#
# order_status —  статус заказа
#
# order_purchase_timestamp —  время создания заказа
#
# order_approved_at —  время подтверждения оплаты заказа
#
# order_delivered_carrier_date —  время передачи заказа в логистическую службу
#
# order_delivered_customer_date —  время доставки заказа
#
# order_estimated_delivery_date —  обещанная дата доставки
#
# <li>olist_order_items_dataset.csv —  товарные позиции, входящие в заказы</li></br>
#
# order_id —  уникальный идентификатор заказа
#
# order_item_id —  идентификатор товара внутри одного заказа
#
# product_id —  ид товара
#
# seller_id — ид производителя товара
#
# shipping_limit_date —  максимальная дата доставки продавцом для передачи заказа партнеру по логистике
#
# price —  цена за единицу товара
#
# freight_value —  вес товара
#
#
# ##### Уникальные статусы заказов в таблице olist_orders_dataset:
#
# created —  создан
# approved —  подтверждён
# invoiced —  выставлен счёт
# processing —  в процессе сборки заказа
# shipped —  отгружен со склада
# delivered —  доставлен пользователю
# unavailable —  недоступен
# canceled —  отменён

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Импортирую библиотеки
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Данные загружены локально
# </div>

# %%
olist_customers_dataset = pd.read_csv('olist_customers_dataset.csv') # таблица с уникальными идентификаторами пользователей
olist_orders_dataset = pd.read_csv('olist_orders_dataset.csv') # таблица заказов
olist_order_items_dataset = pd.read_csv('olist_order_items_dataset.csv') # товарные позиции, входящие в заказы

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Объединяю датасеты
# </div>

# %%
df_merged1 = pd.merge(olist_customers_dataset, olist_orders_dataset, on='customer_id', how='inner')

# %%
df_merged = pd.merge(df_merged1, olist_order_items_dataset, on='order_id', how='left')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Проверяю пропуски
# </div>

# %%
df_merged.isnull().sum()
# Out:
# customer_id                         0
# customer_unique_id                  0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# order_id                            0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 161
# order_delivered_carrier_date     1968
# order_delivered_customer_date    3229
# order_estimated_delivery_date       0
# order_item_id                     775
# product_id                        775
# seller_id                         775
# shipping_limit_date               775
# price                             775
# freight_value                     775
# dtype: int64

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Проверяю дубликаты
# </div>

# %%
df_merged.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Проверяю типы данных
# </div>

# %%
df_merged.dtypes
# Out:
# customer_id                       object
# customer_unique_id                object
# customer_zip_code_prefix           int64
# customer_city                     object
# customer_state                    object
# order_id                          object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# order_item_id                    float64
# product_id                        object
# seller_id                         object
# shipping_limit_date               object
# price                            float64
# freight_value                    float64
# dtype: object

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Преобразую столбцы с датами в datetime формат
# </div>

# %%
df_merged[
    [
        'order_purchase_timestamp',
        'order_approved_at',
        'order_delivered_carrier_date',
        'order_delivered_customer_date',
        'order_estimated_delivery_date',
        'shipping_limit_date'
    ]
] = df_merged[
    [
        'order_purchase_timestamp',
        'order_approved_at',
        'order_delivered_carrier_date',
        'order_delivered_customer_date',
        'order_estimated_delivery_date',
        'shipping_limit_date'
    ]
].apply(pd.to_datetime)

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Проверяю временные рамки транзакций
# </div>

# %%
print(f'min',df_merged.order_purchase_timestamp.min(), f'max', df_merged.order_purchase_timestamp.max())
# Out:
# min 2016-09-04 21:15:19 max 2018-10-17 17:30:18

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Смотрю на распредление заказов в зависимости от статуса
# </div>

# %%
df_merged.groupby("order_status", as_index = False).agg({"customer_id": "count"})
# Out:
#   order_status  customer_id
# 0     approved            3
# 1     canceled          706
# 2      created            5
# 3    delivered       110197
# 4     invoiced          361
# 5   processing          357
# 6      shipped         1186
# 7  unavailable          610

# %% [markdown]
# #### 1. Сколько пользователей, которые совершили покупку только один раз?

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# В качестве покупки буду рассматривать подтверждение заказа (order_approved_at)
# </div>

# %%
task1 = df_merged[df_merged['order_approved_at'].notnull()]

# %%
filtered_df = task1.groupby('customer_unique_id').agg({'order_id': 'nunique'})

# %%
single_purchase_users = len(filtered_df[filtered_df['order_id'] == 1])
single_purchase_users
# Out:
# 93049

# %% [markdown]
# #### 2. Сколько заказов в месяц в среднем не доставляется по разным причинам (вывести детализацию по причинам)?

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Недоставленными считаю заказы со статусом "canceled" и "unavailable"
# </div>

# %%
not_delivered_df = (
    df_merged[df_merged['order_status'].isin(['unavailable', 'canceled'])]
    .groupby('order_status')
    .agg({'order_id': 'nunique'})
    .rename(columns={'order_id': 'order_id_cnt'})
)
not_delivered_df
# Out:
#               order_id_cnt
# order_status
# canceled               625
# unavailable            609

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# На этапе предварительного анализа я выяснил, что разница между самой ранней и самой поздней транзакцией составляет 2г 1месяц или 25 месяцев
# </div>

# %%
not_delivered_df / 25
# Out:
#               order_id_cnt
# order_status
# canceled             25.00
# unavailable          24.36

# %% [markdown]
# #### 3. По каждому товару определить, в какой день недели товар чаще всего покупается.

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Дублирую дф из первого вопроса, т.к. в нем я дал определение покупке
# </div>

# %%
task3 = task1.copy()

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Добавляю столбец с днями недели
# </div>

# %%
task3['day_of_week'] = task1['order_purchase_timestamp'].dt.day_name()

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Считаю количество покупок товара по дням недели
# </div>

# %%
product_day_counts = task2.groupby(['product_id', 'day_of_week']).size().reset_index(name='purchase_count')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Оставляю максимальное количество покупок у каждого товара
# </div>

# %%
max_counts = product_day_counts.groupby('product_id')['purchase_count'].max().reset_index(name='max_purchase_count')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Объединяю максимальное количество покупок с исходной таблицей
# </div>

# %%
result = product_day_counts.merge(max_counts, on='product_id')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Оставляю только те строки, которые равны максимальному значению, чтобы учесть случаи, когда товар продавался одинаково много в различные дни недели
# </div>

# %%
result[result['purchase_count'] == result['max_purchase_count']].sort_values(by='purchase_count', ascending=False).head()
# Out:
#                              product_id day_of_week  purchase_count  \
# 15899  422879e10f46682990de24d770e7f83d   Wednesday              93
# 36507  99a4788cb24856965c36a24e339b6058      Monday              92
# 41039  aca2eb7d00ea1a7b8ebd4e68314663af    Thursday              89
# 20123  53b36df67ebb7c41585e8d54d6772e08     Tuesday              76
# 13534  389d119b48cf3043d311335e499d9c6b    Thursday              67
#
#        max_purchase_count
# 15899                  93
# 36507                  92
# 41039                  89
# 20123                  76
# 13534                  67

# %% [markdown]
# #### 4. Сколько у каждого из пользователей в среднем покупок в неделю (по месяцам)? Нужно учесть, что количество недель в месяце не целое.

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Дублирую дф, определённый как покупка
# </div>

# %%
task4 = task1.copy()

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Меняю дату на месяца
# </div>

# %%
task4['order_purchase_timestamp'] = task4.order_purchase_timestamp.dt.strftime('%Y-%m')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Считаю количество покупок в месяц
# </div>

# %%
orders_in_month = task4.groupby(['customer_unique_id','order_purchase_timestamp']).size().reset_index(name='order_cnt')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Создаю колонку с количеством дней в месяце
# </div>

# %%
orders_in_month['days'] = pd.to_datetime(orders_in_month.order_purchase_timestamp)

# %%
orders_in_month.days = orders_in_month.days.dt.days_in_month

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Считаю количество недель в месяце
# </div>

# %%
orders_in_month['weeks'] = orders_in_month.days / 7

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Считаю количество покупок в неделю по месяцам
# </div>

# %%
orders_in_month['purcheses_a_week'] = orders_in_month.order_cnt/orders_in_month.weeks

# %%
orders_in_month
# Out:
#                      customer_unique_id order_purchase_timestamp  order_cnt  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2                  2018-05          1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f                  2018-05          1
# 2      0000f46a3911fa3c0805444483337064                  2017-03          1
# 3      0000f6ccb0745a6a4b88665a16c9f078                  2017-10          1
# 4      0004aac84e0df4da2b147fca70cf8255                  2017-11          1
# ...                                 ...                      ...        ...
# 97911  fffcf5a5ff07b0908bd4e2dbc735a684                  2017-06          2
# 97912  fffea47cd6d3cc0a88bd621562a9d061                  2017-12          1
# 97913  ffff371b4d645b6ecea244b27531430a                  2017-02          1
# 97914  ffff5962728ec6157033ef9805bacc48                  2018-05          1
# 97915  ffffd2657e2aad2907e67c3e9daecbeb                  2017-05          1
#
#        days     weeks  purcheses_a_week
# 0        31  4.428571          0.225806
# 1        31  4.428571          0.225806
# 2        31  4.428571          0.225806
# 3        31  4.428571          0.225806
# 4        30  4.285714          0.233333
# ...     ...       ...               ...
# 97911    30  4.285714          0.466667
# 97912    31  4.428571          0.225806
# 97913    28  4.000000          0.250000
# 97914    31  4.428571          0.225806
# 97915    31  4.428571          0.225806
#
# [97916 rows x 6 columns]

# %% [markdown]
# #### 5. Выполнить когортный анализ пользователей. В период с января по декабрь выяви когорту с самым высоким retention на 3й месяц.

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Дублирую дф, определённый как покупка
# </div>

# %%
task5 = task1.copy()

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Добавляю дату первой покупки в новый столбец
# </div>

# %%
task5['first_purchase_month'] = task5.groupby('customer_unique_id')['order_purchase_timestamp'].transform('min').dt.to_period('M')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Создаю колонку с месяцем покупки
# </div>

# %%
task5['month'] = task5['order_purchase_timestamp'].dt.to_period('M')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Выявляю количество пользователей, которые совершили первую покупку в определённый месяц и были активны в другие
# </div>

# %%
cohort_data = task5.groupby(['first_purchase_month', 'month']).agg({'customer_unique_id': 'nunique'}).reset_index()

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Создаю столбец с когортным периодом</div>

# %%
cohort_data['cohort_period'] = (cohort_data['month'] - cohort_data['first_purchase_month']).apply(lambda x: x.n)

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Делаю сводную таблицу</div>

# %%
cohort_pivot = cohort_data.pivot_table(index='first_purchase_month', columns='cohort_period', values='customer_unique_id')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Беру размер когорт (первый столбец)</div>

# %%
cohort_size = cohort_pivot.iloc[:, 0]

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Расчитываю ретеншн - процент клиентов, оставшихся активными в каждом когортном периоде, по сравнению с размером когорты:</div>

# %%
retention = cohort_pivot.divide(cohort_size, axis=0)

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Оформляю таблицу</div>

# %%
ur_style = (retention
            .style
            .set_caption('User retention by cohort')  # добавляю подпись
            .background_gradient(cmap='viridis')  # раскрашиваю ячейки по столбцам
            .highlight_null('white')  # делаю белый фон для значений NaN
            .format("{:.2%}", na_rep=""))  # числа форматирую как проценты, NaN заменяем на пустоту
ur_style
# Out:
# <style type="text/css">
# #T_37ecd_row0_col0, #T_37ecd_row1_col0, #T_37ecd_row1_col19, #T_37ecd_row2_col0, #T_37ecd_row3_col0, #T_37ecd_row3_col1, #T_37ecd_row3_col18, #T_37ecd_row4_col0, #T_37ecd_row4_col1, #T_37ecd_row4_col5, #T_37ecd_row4_col8, #T_37ecd_row4_col10, #T_37ecd_row4_col15, #T_37ecd_row4_col16, #T_37ecd_row5_col0, #T_37ecd_row5_col17, #T_37ecd_row6_col0, #T_37ecd_row6_col2, #T_37ecd_row6_col12, #T_37ecd_row6_col14, #T_37ecd_row7_col0, #T_37ecd_row7_col13, #T_37ecd_row8_col0, #T_37ecd_row9_col0, #T_37ecd_row10_col0, #T_37ecd_row11_col0, #T_37ecd_row11_col11, #T_37ecd_row12_col0, #T_37ecd_row12_col3, #T_37ecd_row13_col0, #T_37ecd_row13_col6, #T_37ecd_row13_col9, #T_37ecd_row14_col0, #T_37ecd_row14_col1, #T_37ecd_row14_col7, #T_37ecd_row15_col0, #T_37ecd_row15_col1, #T_37ecd_row16_col0, #T_37ecd_row16_col1, #T_37ecd_row17_col0, #T_37ecd_row17_col4, #T_37ecd_row17_col5, #T_37ecd_row18_col0, #T_37ecd_row19_col0, #T_37ecd_row20_col0, #T_37ecd_row21_col0, #T_37ecd_row22_col0, #T_37ecd_row22_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_37ecd_row0_col1, #T_37ecd_row0_col2, #T_37ecd_row0_col3, #T_37ecd_row0_col4, #T_37ecd_row0_col5, #T_37ecd_row0_col6, #T_37ecd_row0_col7, #T_37ecd_row0_col8, #T_37ecd_row0_col9, #T_37ecd_row0_col10, #T_37ecd_row0_col11, #T_37ecd_row0_col12, #T_37ecd_row0_col13, #T_37ecd_row0_col14, #T_37ecd_row0_col15, #T_37ecd_row0_col16, #T_37ecd_row0_col17, #T_37ecd_row0_col18, #T_37ecd_row1_col1, #T_37ecd_row1_col2, #T_37ecd_row1_col3, #T_37ecd_row1_col4, #T_37ecd_row1_col5, #T_37ecd_row1_col7, #T_37ecd_row1_col8, #T_37ecd_row1_col10, #T_37ecd_row1_col12, #T_37ecd_row1_col14, #T_37ecd_row1_col16, #T_37ecd_row2_col2, #T_37ecd_row2_col3, #T_37ecd_row2_col4, #T_37ecd_row2_col5, #T_37ecd_row2_col6, #T_37ecd_row2_col7, #T_37ecd_row2_col8, #T_37ecd_row2_col9, #T_37ecd_row2_col10, #T_37ecd_row2_col11, #T_37ecd_row2_col12, #T_37ecd_row2_col13, #T_37ecd_row2_col14, #T_37ecd_row2_col15, #T_37ecd_row2_col16, #T_37ecd_row2_col17, #T_37ecd_row2_col18, #T_37ecd_row3_col9, #T_37ecd_row4_col18, #T_37ecd_row5_col18, #T_37ecd_row6_col17, #T_37ecd_row6_col18, #T_37ecd_row7_col16, #T_37ecd_row7_col17, #T_37ecd_row7_col18, #T_37ecd_row8_col15, #T_37ecd_row8_col16, #T_37ecd_row8_col17, #T_37ecd_row8_col18, #T_37ecd_row9_col14, #T_37ecd_row9_col15, #T_37ecd_row9_col16, #T_37ecd_row9_col17, #T_37ecd_row9_col18, #T_37ecd_row10_col13, #T_37ecd_row10_col14, #T_37ecd_row10_col15, #T_37ecd_row10_col16, #T_37ecd_row10_col17, #T_37ecd_row10_col18, #T_37ecd_row11_col12, #T_37ecd_row11_col13, #T_37ecd_row11_col14, #T_37ecd_row11_col15, #T_37ecd_row11_col16, #T_37ecd_row11_col17, #T_37ecd_row11_col18, #T_37ecd_row12_col11, #T_37ecd_row12_col12, #T_37ecd_row12_col13, #T_37ecd_row12_col14, #T_37ecd_row12_col15, #T_37ecd_row12_col16, #T_37ecd_row12_col17, #T_37ecd_row12_col18, #T_37ecd_row13_col10, #T_37ecd_row13_col11, #T_37ecd_row13_col12, #T_37ecd_row13_col13, #T_37ecd_row13_col14, #T_37ecd_row13_col15, #T_37ecd_row13_col16, #T_37ecd_row13_col17, #T_37ecd_row13_col18, #T_37ecd_row14_col9, #T_37ecd_row14_col10, #T_37ecd_row14_col11, #T_37ecd_row14_col12, #T_37ecd_row14_col13, #T_37ecd_row14_col14, #T_37ecd_row14_col15, #T_37ecd_row14_col16, #T_37ecd_row14_col17, #T_37ecd_row14_col18, #T_37ecd_row15_col8, #T_37ecd_row15_col9, #T_37ecd_row15_col10, #T_37ecd_row15_col11, #T_37ecd_row15_col12, #T_37ecd_row15_col13, #T_37ecd_row15_col14, #T_37ecd_row15_col15, #T_37ecd_row15_col16, #T_37ecd_row15_col17, #T_37ecd_row15_col18, #T_37ecd_row16_col7, #T_37ecd_row16_col8, #T_37ecd_row16_col9, #T_37ecd_row16_col10, #T_37ecd_row16_col11, #T_37ecd_row16_col12, #T_37ecd_row16_col13, #T_37ecd_row16_col14, #T_37ecd_row16_col15, #T_37ecd_row16_col16, #T_37ecd_row16_col17, #T_37ecd_row16_col18, #T_37ecd_row17_col6, #T_37ecd_row17_col7, #T_37ecd_row17_col8, #T_37ecd_row17_col9, #T_37ecd_row17_col10, #T_37ecd_row17_col11, #T_37ecd_row17_col12, #T_37ecd_row17_col13, #T_37ecd_row17_col14, #T_37ecd_row17_col15, #T_37ecd_row17_col16, #T_37ecd_row17_col17, #T_37ecd_row17_col18, #T_37ecd_row18_col5, #T_37ecd_row18_col6, #T_37ecd_row18_col7, #T_37ecd_row18_col8, #T_37ecd_row18_col9, #T_37ecd_row18_col10, #T_37ecd_row18_col11, #T_37ecd_row18_col12, #T_37ecd_row18_col13, #T_37ecd_row18_col14, #T_37ecd_row18_col15, #T_37ecd_row18_col16, #T_37ecd_row18_col17, #T_37ecd_row18_col18, #T_37ecd_row19_col4, #T_37ecd_row19_col5, #T_37ecd_row19_col6, #T_37ecd_row19_col7, #T_37ecd_row19_col8, #T_37ecd_row19_col9, #T_37ecd_row19_col10, #T_37ecd_row19_col11, #T_37ecd_row19_col12, #T_37ecd_row19_col13, #T_37ecd_row19_col14, #T_37ecd_row19_col15, #T_37ecd_row19_col16, #T_37ecd_row19_col17, #T_37ecd_row19_col18, #T_37ecd_row20_col3, #T_37ecd_row20_col4, #T_37ecd_row20_col5, #T_37ecd_row20_col6, #T_37ecd_row20_col7, #T_37ecd_row20_col8, #T_37ecd_row20_col9, #T_37ecd_row20_col10, #T_37ecd_row20_col11, #T_37ecd_row20_col12, #T_37ecd_row20_col13, #T_37ecd_row20_col14, #T_37ecd_row20_col15, #T_37ecd_row20_col16, #T_37ecd_row20_col17, #T_37ecd_row20_col18, #T_37ecd_row21_col2, #T_37ecd_row21_col3, #T_37ecd_row21_col4, #T_37 ...
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
# }
# #T_37ecd_row0_col19, #T_37ecd_row2_col19, #T_37ecd_row3_col19, #T_37ecd_row4_col19, #T_37ecd_row5_col19, #T_37ecd_row6_col19, #T_37ecd_row7_col19, #T_37ecd_row8_col19, #T_37ecd_row9_col19, #T_37ecd_row10_col19, #T_37ecd_row11_col19, #T_37ecd_row12_col19, #T_37ecd_row13_col19, #T_37ecd_row14_col19, #T_37ecd_row15_col19, #T_37ecd_row16_col19, #T_37ecd_row17_col19, #T_37ecd_row18_col19, #T_37ecd_row19_col19, #T_37ecd_row20_col19, #T_37ecd_row21_col19, #T_37ecd_row22_col19 {
#   background-color: #440154;
#   color: #f1f1f1;
#   background-color: white;
# }
# #T_37ecd_row1_col6 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_37ecd_row1_col9, #T_37ecd_row1_col15, #T_37ecd_row1_col18, #T_37ecd_row2_col1, #T_37ecd_row3_col6, #T_37ecd_row3_col10, #T_37ecd_row3_col12, #T_37ecd_row3_col13, #T_37ecd_row3_col16, #T_37ecd_row3_col17, #T_37ecd_row5_col8, #T_37ecd_row7_col14, #T_37ecd_row8_col3, #T_37ecd_row8_col11, #T_37ecd_row10_col5, #T_37ecd_row11_col2, #T_37ecd_row11_col4, #T_37ecd_row12_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_37ecd_row1_col11 {
#   background-color: #b0dd2f;
#   color: #000000;
# }
# #T_37ecd_row1_col13, #T_37ecd_row14_col3 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_37ecd_row1_col17 {
#   background-color: #3dbc74;
#   color: #f1f1f1;
# }
# #T_37ecd_row3_col2, #T_37ecd_row13_col5 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_37ecd_row3_col3, #T_37ecd_row10_col8 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_37ecd_row3_col4 {
#   background-color: #7ad151;
#   color: #000000;
# }
# #T_37ecd_row3_col5, #T_37ecd_row6_col13 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_37ecd_row3_col7 {
#   background-color: #355e8d;
#   color: #f1f1f1;
# }
# #T_37ecd_row3_col8 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_37ecd_row3_col11, #T_37ecd_row12_col5, #T_37ecd_row14_col5 {
#   background-color: #404688;
#   color: #f1f1f1;
# }
# #T_37ecd_row3_col14 {
#   background-color: #287d8e;
#   color: #f1f1f1;
# }
# #T_37ecd_row3_col15, #T_37ecd_row5_col11 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_37ecd_row4_col2 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_37ecd_row4_col3, #T_37ecd_row5_col9 {
#   background-color: #481d6f;
#   color: #f1f

# %%
retention[3].idxmax()
# Out:
# Period('2017-06', 'M')

# %% [markdown]
# #### 6. Построить RFM сегментацию пользователей. Для каждого сегмента обозначить границы метрик.

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Дублирую дф, определённый как покупка
# </div>

# %%
task6 = task1.copy()

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Смотрю дату последней покупки
# </div>

# %%
task6.order_purchase_timestamp.max()
# Out:
# Timestamp('2018-09-03 09:06:57')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Устанвливаю дату от которой буду считать recency
# </div>

# %%
today = pd.to_datetime('2018-09-04')

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Группируем данные по customer_unique_id и рассчитываем RFM:<br>
# В recency идёт разница даты today и последней покупки<br>
# В frequency подсчитываем количество заказов пользователя<br>
# В monetary считаем общую сумму заказов
# </div>

# %%
rfm = task6.groupby('customer_unique_id').agg({
    'order_purchase_timestamp': lambda x: (today - x.max()).days, 'order_id': 'nunique', 'price': 'sum'
    }).rename(columns={'order_purchase_timestamp': 'Recency', 'order_id': 'Frequency', 'price': 'Monetary'}).reset_index()

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Присваиваю оценки RFM метрикам по квантилям.<br>
# Из за неравномерного распределения Frequency оценки получились 1 2 3 и 5.<br>
# И я применил pd.cut к Frequency потому, что квантиль выдавал мне только один диапазон
# </div>

# %%
rfm['R_Score'] = pd.qcut(rfm['Recency'], 5, labels=[5, 4, 3, 2, 1]).astype(int)
rfm['F_Score'] = pd.cut(rfm['Frequency'], 5, labels=[1, 2, 3, 4, 5]).astype(int)
rfm['M_Score'] = pd.qcut(rfm['Monetary'], 5, labels=[1, 2, 3, 4, 5]).astype(int)

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Создание столбца с общим RFM Score
# </div>

# %%
rfm['RFM_score'] = rfm['R_Score'].astype(str) + rfm['F_Score'].astype(str) + rfm['M_Score'].astype(str)

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Сегментация клиентов на основе RFM Score<br>
# <br>
# 1. Best Customers (RFM_score = 555):<br>
# Recency: Эти клиенты совершили покупку недавно, в пределах 0–98 дней (лучший квантиль по "недавности").<br>
# Frequency:<br>
# Monetary: Эти клиенты тратят наибольшие суммы — от 179,9 до 13,440  (самая высокая группа по тратам).<br>
# Описание: Это ваши самые ценные клиенты, которые покупают часто, недавно и тратят большие суммы.<br>
# <br>
# 2. Loyal Customers (Recency начинается с 5):<br>
# Recency: Эти клиенты также совершили покупку недавно — от 0 до 98 дней.<br>
# Frequency: Эти клиенты покупают на регулярной основе — высокие значения в пределах от 1 до 16 покупок.<br>
# Monetary: Могут тратить немного меньше, чем лучшие клиенты — диапазон сумм находится между 69.9 и 179.9<br>
# Описание: Это лояльные клиенты, которые покупают регулярно и недавно, но их траты могут быть немного ниже, чем у лучших клиентов.<br>
# <br>
# 3. At Risk (Recency начинается с 1):<br>
# Recency: Клиенты, которые давно не совершали покупок — от 389 до 729 дней.<br>
# Frequency: Эти клиенты, вероятно, покупали редко — от 1 до 16 покупок.<br>
# Monetary: Суммы покупок могли варьироваться от 8.5 до 39.9<br>
# Описание: Это клиенты, которые находятся в зоне риска, они не возвращались давно и не были особенно активны.<br>
# <br>
# 4. Others:<br>
# Recency: Эти клиенты могут совершать покупки в среднем диапазоне времени — от 98 до 389 дней назад.<br>
# Frequency: Частота их покупок, как правило, варьируется от 1 до 16 покупок.<br>
# Monetary: Траты могут находиться в диапазоне от 39.9 до 179.9<br>
# Описание: Это клиенты со средней активностью и тратами, которые не выделяются ни в лучшую, ни в худшую сторону.<br>
# <br>
# Примечание:<br>
# Границы для Recency варьируются от 0 до 729 дней, что указывает на недавних клиентов и тех, кто долго не возвращался.<br>
# Frequency имеет диапазон от 1 до 16 заказов<br>
# Monetary варьируется значительно, с минимальной тратой в 8.5 и максимальной до 13,440<br>
# </div>

# %%
def segment_rfm(df):
    if df['RFM_score'] == '555':
        return 'Best Customers'
    elif df['RFM_score'][0] == '5':
        return 'Loyal Customers'
    elif df['RFM_score'][0] == '1':
        return 'At Risk'
    else:
        return 'Others'
    
rfm['Segment'] = rfm.apply(segment_rfm, axis=1)

# %%
rfm
# Out:
#                      customer_unique_id  Recency  Frequency  Monetary  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      116          1    129.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      119          1     18.90
# 2      0000f46a3911fa3c0805444483337064      542          1     69.00
# 3      0000f6ccb0745a6a4b88665a16c9f078      326          1     25.99
# 4      0004aac84e0df4da2b147fca70cf8255      293          1    180.00
# ...                                 ...      ...        ...       ...
# 95415  fffcf5a5ff07b0908bd4e2dbc735a684      452          1   1570.00
# 95416  fffea47cd6d3cc0a88bd621562a9d061      267          1     64.89
# 95417  ffff371b4d645b6ecea244b27531430a      573          1     89.90
# 95418  ffff5962728ec6157033ef9805bacc48      124          1    115.00
# 95419  ffffd2657e2aad2907e67c3e9daecbeb      489          1     56.99
#
#        R_Score  F_Score  M_Score RFM_score  Segment
# 0            4        1        4       414   Others
# 1            4        1        1       411   Others
# 2            1        1        2       112  At Risk
# 3            2        1        1       211   Others
# 4            2        1        5       215   Others
# ...        ...      ...      ...       ...      ...
# 95415        1        1        5       115  At Risk
# 95416        3        1        2       312   Others
# 95417        1        1        3       113  At Risk
# 95418        4        1        4       414   Others
# 95419        1        1        2       112  At Risk
#
# [95420 rows x 9 columns]

# %% [markdown]
# <div style="background-color: #d9f2fa; padding: 10px; border-radius: 5px;">
# Границы квантилей
# </div>

# %%
recency_quantiles = pd.qcut(rfm['Recency'], 5, labels=False, retbins=True, duplicates='drop')
frequency_quantiles = pd.cut(rfm['Frequency'], 5, labels=False, retbins=True, duplicates='drop')
monetary_quantiles = pd.qcut(rfm['Monetary'], 5, labels=False, retbins=True, duplicates='drop')

print("Границы Recency:\n", recency_quantiles[1])
print("Границы Frequency:\n", frequency_quantiles[1])
print("Границы Monetary:\n", monetary_quantiles[1])
# Out:
# Границы Recency:
#  [  0.  98. 183. 274. 389. 729.]
# Границы Frequency:
#  [ 0.984  4.2    7.4   10.6   13.8   17.   ]
# Границы Monetary:
#  [    0.     39.     69.    109.9   179.9 13440. ]
